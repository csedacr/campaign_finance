# %%
import pandas as pd

# %%
adams = pd.read_csv('../data/CFB_adams.csv')

# %%
adams.head()
# Out:
#    ELECTION  OFFICECD  RECIPID CANCLASS      RECIPNAME COMMITTEE  FILING  \
# 0      2025         1     1545        P  Adams, Eric L         N       6
# 1      2025         1     1545        P  Adams, Eric L         N       7
# 2      2025         1     1545        P  Adams, Eric L         N       6
# 3      2025         1     1545        P  Adams, Eric L         N       6
# 4      2025         1     1545        P  Adams, Eric L         N       6
#
#   SCHEDULE  PAGENO  SEQUENCENO  ... INTEMPSTNM INTEMPCITY INTEMPST INTOCCUPA  \
# 0      ABC     NaN         NaN  ...        NaN        NaN      NaN       NaN
# 1      ABC     NaN         NaN  ...        NaN        NaN      NaN       NaN
# 2      ABC     NaN         NaN  ...        NaN        NaN      NaN       NaN
# 3      ABC     NaN         NaN  ...        NaN        NaN      NaN       NaN
# 4      ABC     NaN         NaN  ...        NaN        NaN      NaN       NaN
#
#   PURPOSECD  EXEMPTCD  ADJTYPECD  RR_IND SEG_IND INT_C_CODE
# ...

# %%
adams = adams[['RECIPNAME', 'DATE', 'REFUNDDATE', 'NAME', 'CITY', 'STATE', 'ZIP', 'OCCUPATION', 'EMPNAME', 'EMPSTRNO', 'EMPSTRNAME', 'EMPCITY', 'EMPSTATE', 'AMNT', 'MATCHAMNT']]

# %%
adams[adams.duplicated(['NAME'], keep=False)]
# Out:
#          RECIPNAME       DATE REFUNDDATE                 NAME           CITY  \
# 119  Adams, Eric L  8/23/2024        NaN  Cooperstone, Elliot   East Hampton
# 120  Adams, Eric L  8/23/2024  12/6/2024  Cooperstone, Elliot   East Hampton
# 124  Adams, Eric L  8/16/2024        NaN           Curtis, Al  Staten Island
# 125  Adams, Eric L  8/16/2024   9/4/2024           Curtis, Al  Staten Island
# 130  Adams, Eric L   1/9/2025        NaN      DeLusant, Steve        Hoboken
# ..             ...        ...        ...                  ...            ...
# 762  Adams, Eric L  1/10/2025        NaN        Zamora, Pedro  East Elmhurst
# 769  Adams, Eric L  8/20/2024        NaN         Zhang, Baoli  Staten Island
# 770  Adams, Eric L  8/20/2024  12/6/2024         Zhang, Baoli  Staten Island
# 774  Adams, Eric L  7/10/2024        NaN          Zhao, Larry       Brooklyn
# 775  Adams, Eric L  7/10/2024  12/6/2024          Zhao, Larry       Brooklyn
#
# ...

# %%
adams_clean = adams.drop_duplicates(subset="NAME")

# %%
adams_clean
# Out:
#          RECIPNAME       DATE REFUNDDATE                   NAME  \
# 0    Adams, Eric L  8/29/2024        NaN  Abduganiev, Maksudjon
# 1    Adams, Eric L   1/8/2025        NaN       Abrahimi, Farhad
# 2    Adams, Eric L  8/11/2024        NaN         Acevedo, Isaac
# 3    Adams, Eric L  8/14/2024        NaN       Acevedo, Melissa
# 4    Adams, Eric L  8/15/2024        NaN          Achille, Carl
# ..             ...        ...        ...                    ...
# 783  Adams, Eric L   7/8/2024        NaN        Zhuo, Xiao  Wen
# 784  Adams, Eric L  7/17/2024        NaN      Zimmerman, Joseph
# 785  Adams, Eric L   1/9/2025        NaN        Zirkiev, Shalom
# 786  Adams, Eric L  7/25/2024        NaN             Zou, Raina
# 787  Adams, Eric L   1/7/2025        NaN       Zupnick, Eliezer
#
#               CITY STATE    ZIP              OCCUPATION  \
# 0         Brooklyn    NY  11229              Dispatcher
# 1       Hicksville    NY  11801                Business
# ...

# %%
adams_clean.to_csv('../output/adams_clean.csv')
