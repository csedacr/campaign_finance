# %%
import pandas as pd

# %%
adams = pd.read_csv('../output/adams_clean.csv')
lander = pd.read_csv('../output/lander_clean.csv')
ramos = pd.read_csv('../output/ramos_clean.csv')
myrie = pd.read_csv('../output/myrie_clean.csv')
mamdani = pd.read_csv('../output/mamdani_clean.csv')
stringer = pd.read_csv('../output/stringer_clean.csv')

# %%
all_clean = pd.concat([ adams, lander, mamdani, myrie, ramos, stringer ])
print(len(all_clean))
# Out:
# 16028

# %%
all_clean
# Out:
#       Unnamed: 0          RECIPNAME        DATE REFUNDDATE  \
# 0              0      Adams, Eric L   8/29/2024        NaN
# 1              1      Adams, Eric L    1/8/2025        NaN
# 2              2      Adams, Eric L   8/11/2024        NaN
# 3              3      Adams, Eric L   8/14/2024        NaN
# 4              4      Adams, Eric L   8/15/2024        NaN
# ...          ...                ...         ...        ...
# 2140        3175  Stringer, Scott M    9/8/2024        NaN
# 2141        3176  Stringer, Scott M  11/25/2024        NaN
# 2142        3177  Stringer, Scott M   10/7/2024        NaN
# 2143        3178  Stringer, Scott M   12/2/2024        NaN
# 2144        3179  Stringer, Scott M   9/29/2024        NaN
#
#                        NAME           CITY STATE    ZIP         OCCUPATION  \
# 0     Abduganiev, Maksudjon       Brooklyn    NY  11229         Dispatcher
# 1          Abrahimi, Farhad     Hicksville    NY  11801           Business
# 2            Acevedo, Isaac  Staten Island    NY  10303       Not Employed
# 3          Acevedo, Melissa  Staten Island    NY  10303                 RN
# 4             Achille, Carl    Alden Manor    NY  11003           Sergeant
# ...                     ...            ...   ...    ...                ...
# 2140            Zou, Fenger       Flushing    NY  11362  Real Estate Agent
# 2141           Zou, Min Fen       Brooklyn    NY  11214      Floor manager
# 2142          Zrake, Donald      Levittown    NY  11756           Engineer
# 2143         Zukowski, Cris       New York    NY  10128         unemployed
# 2144       Zurkow, Benjamin       New York    NY  10075  Software Engineer
#
#                              EMPNAME EMPSTRNO         EMPSTRNAME  \
# 0     Dispatch Limo Seven Transporta      653       E 5th Street
# 1                      Self-Employed        9  West Marie Street
# 2                       Not Employed      NaN                NaN
# 3     Richmond Univeristy Medical Ce      355           Bard Ave
# 4     New York City Police Departmen        8    Catherine Court
# ...                              ...      ...                ...
# 2140         Fengz International INC    34-36       Union Street
# 2141                     Min Fen Zou     6812        15th Avenue
# 2142              Hallam Engineering    97-37           63rd Dr.
# 2143                      unemployed      NaN                NaN
# 2144                Copia Automation       43   West 24th Street
#
#             EMPCITY EMPSTATE   AMNT  MATCHAMNT
# 0          Brooklyn       NY  250.0      250.0
# 1        Hicksville       NY  500.0        0.0
# 2               NaN      NaN  250.0      250.0
# 3     Staten Island       NY  250.0      250.0
# 4       Alden Manor       NY  250.0        0.0
# ...             ...      ...    ...        ...
# 2140       Flushing       NY  250.0      250.0
# 2141       Brooklyn       NY  250.0      250.0
# 2142       Flushing       NY   75.0        0.0
# 2143            NaN      NaN   30.0       30.0
# 2144       New York       NY  500.0      250.0
#
# [16028 rows x 16 columns]

# %%
all_clean = all_clean [['RECIPNAME', 'DATE', 'REFUNDDATE', 'NAME', 'CITY', 'STATE', 'ZIP', 'OCCUPATION', 'EMPNAME', 'EMPSTRNO', 'EMPSTRNAME', 'EMPCITY', 'EMPSTATE', 'AMNT', 'MATCHAMNT']]

# %%
all_clean
# Out:
#               RECIPNAME        DATE REFUNDDATE                   NAME  \
# 0         Adams, Eric L   8/29/2024        NaN  Abduganiev, Maksudjon
# 1         Adams, Eric L    1/8/2025        NaN       Abrahimi, Farhad
# 2         Adams, Eric L   8/11/2024        NaN         Acevedo, Isaac
# 3         Adams, Eric L   8/14/2024        NaN       Acevedo, Melissa
# 4         Adams, Eric L   8/15/2024        NaN          Achille, Carl
# ...                 ...         ...        ...                    ...
# 2140  Stringer, Scott M    9/8/2024        NaN            Zou, Fenger
# 2141  Stringer, Scott M  11/25/2024        NaN           Zou, Min Fen
# 2142  Stringer, Scott M   10/7/2024        NaN          Zrake, Donald
# 2143  Stringer, Scott M   12/2/2024        NaN         Zukowski, Cris
# 2144  Stringer, Scott M   9/29/2024        NaN       Zurkow, Benjamin
#
#                CITY STATE    ZIP         OCCUPATION  \
# 0          Brooklyn    NY  11229         Dispatcher
# 1        Hicksville    NY  11801           Business
# 2     Staten Island    NY  10303       Not Employed
# 3     Staten Island    NY  10303                 RN
# 4       Alden Manor    NY  11003           Sergeant
# ...             ...   ...    ...                ...
# 2140       Flushing    NY  11362  Real Estate Agent
# 2141       Brooklyn    NY  11214      Floor manager
# 2142      Levittown    NY  11756           Engineer
# 2143       New York    NY  10128         unemployed
# 2144       New York    NY  10075  Software Engineer
#
#                              EMPNAME EMPSTRNO         EMPSTRNAME  \
# 0     Dispatch Limo Seven Transporta      653       E 5th Street
# 1                      Self-Employed        9  West Marie Street
# 2                       Not Employed      NaN                NaN
# 3     Richmond Univeristy Medical Ce      355           Bard Ave
# 4     New York City Police Departmen        8    Catherine Court
# ...                              ...      ...                ...
# 2140         Fengz International INC    34-36       Union Street
# 2141                     Min Fen Zou     6812        15th Avenue
# 2142              Hallam Engineering    97-37           63rd Dr.
# 2143                      unemployed      NaN                NaN
# 2144                Copia Automation       43   West 24th Street
#
#             EMPCITY EMPSTATE   AMNT  MATCHAMNT
# 0          Brooklyn       NY  250.0      250.0
# 1        Hicksville       NY  500.0        0.0
# 2               NaN      NaN  250.0      250.0
# 3     Staten Island       NY  250.0      250.0
# 4       Alden Manor       NY  250.0        0.0
# ...             ...      ...    ...        ...
# 2140       Flushing       NY  250.0      250.0
# 2141       Brooklyn       NY  250.0      250.0
# 2142       Flushing       NY   75.0        0.0
# 2143            NaN      NaN   30.0       30.0
# 2144       New York       NY  500.0      250.0
#
# [16028 rows x 15 columns]

# %%
all_clean = all_clean[all_clean.duplicated(['NAME'], keep=False)]

# %%
all_clean
# Out:
#               RECIPNAME        DATE REFUNDDATE              NAME  \
# 77        Adams, Eric L    7/8/2024        NaN       Chan, Kenny
# 86        Adams, Eric L    7/9/2024        NaN      Chen, Ji Hua
# 93        Adams, Eric L   7/10/2024        NaN         Chen, Xiu
# 96        Adams, Eric L    7/8/2024        NaN      Chen, Yufeng
# 248       Adams, Eric L   7/25/2024        NaN     He, Fang Quan
# ...                 ...         ...        ...               ...
# 1845  Stringer, Scott M   8/30/2024        NaN   Villafane, Enid
# 1881  Stringer, Scott M   12/5/2024        NaN       Wang, Mandy
# 1942  Stringer, Scott M   9/17/2024        NaN  Werksman, Nathan
# 1986  Stringer, Scott M    1/2/2025        NaN  Woolever, Laurie
# 1998  Stringer, Scott M  12/19/2024        NaN        Wu, Johnny
#
#                  CITY STATE    ZIP          OCCUPATION  \
# 77            Bayside    NY  11361                 NaN
# 86           Brooklyn    NY  11220      Home Assistant
# 93           Flushing    NY  11354                 CEO
# 96           Brooklyn    NY  11220                 NaN
# 248          Flushing    NY  11355  Real estate broker
# ...               ...   ...    ...                 ...
# 1845         New York    NY  10019          unemployed
# 1881         FLUSHING    NY  11354             Manager
# 1942         Brooklyn    NY  11201            Attorney
# 1986  Jackson Heights    NY  11372              Writer
# 1998         Brooklyn    NY  11209             Manager
#
#                         EMPNAME EMPSTRNO               EMPSTRNAME  \
# 77                Self Employed     4534             202nd Street
# 86                    True Care      812              60th Street
# 93           Benu Naturans Inc.    13694         Roosevelt Avenue
# 96                      Retired      NaN                      NaN
# 248               Self employed    44-15  College Point Boulevard
# ...                         ...      ...                      ...
# 1845                 unemployed      NaN                      NaN
# 1881     Murray Hill Management    38-15             149th Street
# 1942                 Merson Law       22         West 66th Street
# 1986              Self-Employed      672           Dogwood Avenue
# 1998  Fortune Palace Restaurant     8609                 20th AVe
#
#               EMPCITY EMPSTATE    AMNT  MATCHAMNT
# 77            Bayside       NY   250.0      250.0
# 86           Brooklyn       NY   250.0      250.0
# 93           Flushing       NY   250.0      250.0
# 96                NaN      NaN   250.0      250.0
# 248            Queens       NY   250.0      250.0
# ...               ...      ...     ...        ...
# 1845              NaN      NaN    20.0       20.0
# 1881         Flushing       NY   500.0      250.0
# 1942         New York       NY   150.0        0.0
# 1986  Franklin Square       NY    50.0       50.0
# 1998         Brooklyn       NY  2000.0      250.0
#
# [1367 rows x 15 columns]

# %%
duplicates = all_clean.groupby("NAME")["RECIPNAME"].apply(list)

# %%
duplicates
# Out:
# NAME
# Abarbanel, Aliza                        [Mamdani, Zohran K, Myrie, Zellnor]
# Abate, Liam               [Lander, Brad, Myrie, Zellnor, Stringer, Scott M]
# Aca, Ricardo                            [Mamdani, Zohran K, Ramos, Jessica]
# Acevedo, Jose                           [Mamdani, Zohran K, Myrie, Zellnor]
# Acton-Bond, Brandon                       [Lander, Brad, Mamdani, Zohran K]
#                                                 ...
# Zeno, Mark                                   [Lander, Brad, Myrie, Zellnor]
# Zimmerman, Sandy                             [Lander, Brad, Myrie, Zellnor]
# Zulack, Mary                                 [Lander, Brad, Myrie, Zellnor]
# danon, kenan                            [Mamdani, Zohran K, Myrie, Zellnor]
# van der Meulen, Pamela                    [Lander, Brad, Stringer, Scott M]
# Name: RECIPNAME, Length: 635, dtype: object
