# %%
import pandas as pd

# %%
mamdani = pd.read_csv('../data/CFB_mamdani.csv')

# %%
mamdani = mamdani[['RECIPNAME', 'DATE', 'REFUNDDATE', 'NAME', 'CITY', 'STATE', 'ZIP', 'OCCUPATION', 'EMPNAME', 'EMPSTRNO', 'EMPSTRNAME', 'EMPCITY', 'EMPSTATE', 'AMNT', 'MATCHAMNT']]

# %%
mamdani[mamdani.duplicated(['NAME'], keep=False)]
# Out:
#               RECIPNAME        DATE REFUNDDATE              NAME      CITY  \
# 7     Mamdani, Zohran K  10/23/2024        NaN     Abbot, Thomas  Brooklyn
# 8     Mamdani, Zohran K   1/11/2025        NaN     Abbot, Thomas  Brooklyn
# 10    Mamdani, Zohran K  11/21/2024        NaN  Abdelfatah, Mona  Brooklyn
# 11    Mamdani, Zohran K  12/17/2024        NaN  Abdelfatah, Mona  Brooklyn
# 12    Mamdani, Zohran K   1/11/2025        NaN  Abdelfatah, Mona  Brooklyn
# ...                 ...         ...        ...               ...       ...
# 8260  Mamdani, Zohran K  10/24/2024        NaN      Zucker, Alex  Brooklyn
# 8261  Mamdani, Zohran K  12/18/2024        NaN      Zucker, Alex  Brooklyn
# 8264  Mamdani, Zohran K  10/23/2024        NaN     Zwick, Winnie  Brooklyn
# 8265  Mamdani, Zohran K   12/4/2024        NaN     Zwick, Winnie  Brooklyn
# 8266  Mamdani, Zohran K  11/30/2024        NaN     Zwick, Winnie  Brooklyn
#
# ...

# %%
mamdani_clean = mamdani.drop_duplicates(subset="NAME")

# %%
mamdani_clean.to_csv('../output/mamdani_clean.csv')
