# %%
import pandas as pd

# %%
stringer = pd.read_csv('../data/CFB_stringer.csv')

# %%
stringer = stringer[['RECIPNAME', 'DATE', 'REFUNDDATE', 'NAME', 'CITY', 'STATE', 'ZIP', 'OCCUPATION', 'EMPNAME', 'EMPSTRNO', 'EMPSTRNAME', 'EMPCITY', 'EMPSTATE', 'AMNT', 'MATCHAMNT']]

# %%
stringer[stringer.duplicated(['NAME'], keep=False)]
# Out:
#               RECIPNAME        DATE REFUNDDATE               NAME        CITY  \
# 2     Stringer, Scott M   8/31/2024        NaN        Abate, Liam     Astoria
# 3     Stringer, Scott M   9/20/2024        NaN        Abate, Liam     Astoria
# 5     Stringer, Scott M    8/2/2024        NaN  Abramov, Theodore    New York
# 6     Stringer, Scott M  11/22/2024        NaN  Abramov, Theodore    New York
# 8     Stringer, Scott M   10/5/2024        NaN     Abuelo, Vivian    New York
# ...                 ...         ...        ...                ...         ...
# 3117  Stringer, Scott M    1/7/2025        NaN      Zerkin, Roger   Rego Park
# 3124  Stringer, Scott M   10/4/2024        NaN       Zhang, Jenny    New York
# 3125  Stringer, Scott M   10/5/2024        NaN       Zhang, Jenny    Flushing
# 3133  Stringer, Scott M   8/20/2024        NaN        Zhang, Xiao     Bayside
# 3134  Stringer, Scott M   10/5/2024        NaN        Zhang, Xiao  Whitestone
#
# ...

# %%
stringer_clean = stringer.drop_duplicates(subset="NAME")

# %%
stringer_clean.to_csv('../output/stringer_clean.csv')
