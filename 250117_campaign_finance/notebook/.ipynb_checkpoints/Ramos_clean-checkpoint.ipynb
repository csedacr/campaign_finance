# %%
import pandas as pd

# %%
ramos = pd.read_csv('../data/CFB_ramos.csv')

# %%
ramos = ramos[['RECIPNAME', 'DATE', 'REFUNDDATE', 'NAME', 'CITY', 'STATE', 'ZIP', 'OCCUPATION', 'EMPNAME', 'EMPSTRNO', 'EMPSTRNAME', 'EMPCITY', 'EMPSTATE', 'AMNT', 'MATCHAMNT']]

# %%
ramos[ramos.duplicated(['NAME'], keep=False)]
# Out:
#            RECIPNAME       DATE REFUNDDATE              NAME  \
# 1     Ramos, Jessica  9/19/2024        NaN     Abel Arcia, E
# 2     Ramos, Jessica  9/25/2024        NaN     Abel Arcia, E
# 3     Ramos, Jessica  10/6/2024        NaN     Abel Arcia, E
# 4     Ramos, Jessica  9/18/2024        NaN      Aca, Ricardo
# 5     Ramos, Jessica  1/11/2025        NaN      Aca, Ricardo
# ...              ...        ...        ...               ...
# 1534  Ramos, Jessica  1/11/2025        NaN  Winsten, Richard
# 1537  Ramos, Jessica  9/30/2024        NaN    Wolaver, Marta
# 1538  Ramos, Jessica  12/1/2024        NaN    Wolaver, Marta
# 1550  Ramos, Jessica  9/25/2024        NaN     Yong, Felicia
# 1551  Ramos, Jessica   1/4/2025        NaN     Yong, Felicia
#
#                   CITY STATE    ZIP                      OCCUPATION  \
# 1          Garden City    NY  11530                        Attorney
# 2          Garden City    NY  11530                        Attorney
# ...

# %%
ramos_clean = ramos.drop_duplicates(subset="NAME")

# %%
ramos_clean .to_csv('../output/ramos_clean.csv')
