# %%
import pandas as pd

# %%
lander = pd.read_csv('../data/CFB_lander.csv')

# %%
lander = lander[['RECIPNAME', 'DATE', 'REFUNDDATE', 'NAME', 'CITY', 'STATE', 'ZIP', 'OCCUPATION', 'EMPNAME', 'EMPSTRNO', 'EMPSTRNAME', 'EMPCITY', 'EMPSTATE', 'AMNT', 'MATCHAMNT']]

# %%
lander[lander.duplicated(['NAME'], keep=False)]
# Out:
#          RECIPNAME        DATE REFUNDDATE            NAME      CITY STATE  \
# 1     Lander, Brad   7/31/2024        NaN     Abate, Liam    Queens    NY
# 2     Lander, Brad   8/31/2024        NaN     Abate, Liam    Queens    NY
# 3     Lander, Brad   9/20/2024        NaN     Abate, Liam    Queens    NY
# 4     Lander, Brad   9/30/2024        NaN     Abate, Liam    Queens    NY
# 5     Lander, Brad  10/31/2024        NaN     Abate, Liam    Queens    NY
# ...            ...         ...        ...             ...       ...   ...
# 5107  Lander, Brad   7/30/2024        NaN  Zimmerman, Lee  Brooklyn    NY
# 5108  Lander, Brad   8/15/2024        NaN  Zimmerman, Lee  Brooklyn    NY
# 5116  Lander, Brad   7/31/2024        NaN       Ziv, Maya  Brooklyn    NY
# 5117  Lander, Brad   8/31/2024        NaN       Ziv, Maya  Brooklyn    NY
# 5118  Lander, Brad   9/30/2024        NaN       Ziv, Maya  Brooklyn    NY
#
#         ZIP  OCCUPATION                  EMPNAME EMPSTRNO        EMPSTRNAME  \
# ...

# %%
lander_clean = lander.drop_duplicates(subset="NAME")

# %%
lander_clean
# Out:
#          RECIPNAME        DATE REFUNDDATE                 NAME  \
# 0     Lander, Brad   7/30/2024        NaN       Aaronson, Mark
# 1     Lander, Brad   7/31/2024        NaN          Abate, Liam
# 7     Lander, Brad   7/26/2024        NaN    Abdessalam, Zayne
# 9     Lander, Brad    1/7/2025        NaN       Abeles, Murray
# 10    Lander, Brad  12/13/2024        NaN      Abraham, Jamili
# ...            ...         ...        ...                  ...
# 5120  Lander, Brad   9/17/2024        NaN  Zoll-Phelan, Ericka
# 5121  Lander, Brad   7/30/2024        NaN       Zollar, Jawole
# 5122  Lander, Brad  12/11/2024        NaN         Zulack, Mary
# 5123  Lander, Brad   8/29/2024        NaN      Zulkowitz, zool
# 5124  Lander, Brad   7/30/2024        NaN       Zwerling, Cara
#
#                  CITY STATE    ZIP                      OCCUPATION  \
# 0             Oakland    CA  94618                    Not employed
# 1              Queens    NY  11104                       Bartender
# ...

# %%
lander_clean.to_csv('../output/lander_clean.csv')
