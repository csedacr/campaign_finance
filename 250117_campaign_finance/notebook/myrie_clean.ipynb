# %%
import pandas as pd

# %%
myrie = pd.read_csv('../data/CFB_myrie.csv')

# %%
myrie = myrie[['RECIPNAME', 'DATE', 'REFUNDDATE', 'NAME', 'CITY', 'STATE', 'ZIP', 'OCCUPATION', 'EMPNAME', 'EMPSTRNO', 'EMPSTRNAME', 'EMPCITY', 'EMPSTATE', 'AMNT', 'MATCHAMNT']]

# %%
myrie[myrie.duplicated(['NAME'], keep=False)]
# Out:
#            RECIPNAME        DATE REFUNDDATE            NAME       CITY STATE  \
# 0     Myrie, Zellnor   12/6/2024        NaN    Aaker, Julia   Brooklyn    NY
# 1     Myrie, Zellnor   1/11/2025        NaN    Aaker, Julia   Brooklyn    NY
# 4     Myrie, Zellnor   7/21/2024        NaN     Abate, Liam     Queens    NY
# 5     Myrie, Zellnor   8/21/2024        NaN     Abate, Liam     Queens    NY
# 6     Myrie, Zellnor   8/31/2024        NaN     Abate, Liam     Queens    NY
# ...              ...         ...        ...             ...        ...   ...
# 2815  Myrie, Zellnor   1/11/2025        NaN      Zeno, Mark  Manhattan    NY
# 2819  Myrie, Zellnor  12/13/2024        NaN  Zolot, Barbara   New York    NY
# 2820  Myrie, Zellnor   1/11/2025        NaN  Zolot, Barbara   New York    NY
# 2823  Myrie, Zellnor   9/14/2024        NaN    Zulack, Mary   Brooklyn    NY
# 2824  Myrie, Zellnor   1/11/2025        NaN    Zulack, Mary   Brooklyn    NY
#
# ...

# %%
myrie_clean = myrie.drop_duplicates(subset="NAME")

# %%
myrie_clean.to_csv('../output/myrie_clean.csv')
