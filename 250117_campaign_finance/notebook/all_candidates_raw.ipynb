# %%
import pandas as pd

# %%
adams = pd.read_csv('../data/CFB_adams.csv')
lander = pd.read_csv('../data/CFB_lander.csv')
mamdani = pd.read_csv('../data/CFB_mamdani.csv')
myrie = pd.read_csv('../data/CFB_myrie.csv')
ramos = pd.read_csv('../data/CFB_ramos.csv')
stringer = pd.read_csv('../data/CFB_stringer.csv')

# %%
all_candidates = pd.concat([ adams, lander, mamdani, myrie, ramos, stringer ])
print(len(all_candidates))
# Out:
# 21752

# %%
all_candidates.head()
# Out:
#    ELECTION  OFFICECD  RECIPID CANCLASS      RECIPNAME COMMITTEE  FILING  \
# 0      2025         1     1545        P  Adams, Eric L         N       6
# 1      2025         1     1545        P  Adams, Eric L         N       7
# 2      2025         1     1545        P  Adams, Eric L         N       6
# 3      2025         1     1545        P  Adams, Eric L         N       6
# 4      2025         1     1545        P  Adams, Eric L         N       6
#
#   SCHEDULE  PAGENO  SEQUENCENO  ... INTEMPSTNM INTEMPCITY INTEMPST INTOCCUPA  \
# 0      ABC     NaN         NaN  ...        NaN        NaN      NaN       NaN
# 1      ABC     NaN         NaN  ...        NaN        NaN      NaN       NaN
# 2      ABC     NaN         NaN  ...        NaN        NaN      NaN       NaN
# 3      ABC     NaN         NaN  ...        NaN        NaN      NaN       NaN
# 4      ABC     NaN         NaN  ...        NaN        NaN      NaN       NaN
#
#   PURPOSECD  EXEMPTCD  ADJTYPECD  RR_IND SEG_IND INT_C_CODE
# 0       NaN       NaN        NaN       N       N        NaN
# 1       NaN       NaN        NaN       N       N        NaN
# 2       NaN       NaN        NaN       N       N        NaN
# 3       NaN       NaN        NaN       N       N        NaN
# 4       NaN       NaN        NaN       N       N        NaN
#
# [5 rows x 52 columns]

# %%
all_candidates = all_candidates [['RECIPNAME', 'DATE', 'REFUNDDATE', 'NAME', 'CITY', 'STATE', 'ZIP', 'OCCUPATION', 'EMPNAME', 'EMPSTRNO', 'EMPSTRNAME', 'EMPCITY', 'EMPSTATE', 'AMNT', 'MATCHAMNT']]

# %%
all_candidates.head()
# Out:
#        RECIPNAME       DATE REFUNDDATE                   NAME           CITY  \
# 0  Adams, Eric L  8/29/2024        NaN  Abduganiev, Maksudjon       Brooklyn
# 1  Adams, Eric L   1/8/2025        NaN       Abrahimi, Farhad     Hicksville
# 2  Adams, Eric L  8/11/2024        NaN         Acevedo, Isaac  Staten Island
# 3  Adams, Eric L  8/14/2024        NaN       Acevedo, Melissa  Staten Island
# 4  Adams, Eric L  8/15/2024        NaN          Achille, Carl    Alden Manor
#
#   STATE    ZIP    OCCUPATION                         EMPNAME EMPSTRNO  \
# 0    NY  11229    Dispatcher  Dispatch Limo Seven Transporta      653
# 1    NY  11801      Business                   Self-Employed        9
# 2    NY  10303  Not Employed                    Not Employed      NaN
# 3    NY  10303            RN  Richmond Univeristy Medical Ce      355
# 4    NY  11003      Sergeant  New York City Police Departmen        8
#
#           EMPSTRNAME        EMPCITY EMPSTATE   AMNT  MATCHAMNT
# 0       E 5th Street       Brooklyn       NY  250.0      250.0
# 1  West Marie Street     Hicksville       NY  500.0        0.0
# 2                NaN            NaN      NaN  250.0      250.0
# 3           Bard Ave  Staten Island       NY  250.0      250.0
# 4    Catherine Court    Alden Manor       NY  250.0        0.0

# %%
all_candidates.to_csv('../output/all_candidates_raw.csv')
